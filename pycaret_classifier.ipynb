# %% [markdown]
# # Pycaret Classification

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Sample_Data_set-1

# %%
crop = pd.read_csv(r"C:\Users\Sirisha\pycaret_classification\sample-data\Crop_recommendation.csv")
crop
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# ### Sample_Data_set-2

# %%
wine = pd.read_csv(r"C:\Users\Sirisha\pycaret_classification\sample-data\winequality-red.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Sample_Data_set-3

# %%
diabetes = pd.read_csv(r"C:\Users\Sirisha\pycaret_classification\sample-data\diabetes.csv")
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Setting up Enviroment

# %%
from pycaret.classification import *

# %%
crop_df = setup(crop,target='label')
crop_df
# Out:
# <style type="text/css">
# #T_ebc2d_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ebc2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebc2d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ebc2d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebc2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebc2d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ebc2d_row0_col1" class="data row0 col1" >5680</td>
#     </tr>
#     <tr>
#       <th id="T_ebc2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebc2d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ebc2d_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_ebc2d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
wine_df = setup(wine,target='quality')
wine_df
# Out:
# <style type="text/css">
# #T_a664c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a664c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a664c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a664c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a664c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a664c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a664c_row0_col1" class="data row0 col1" >2019</td>
#     </tr>
#     <tr>
#       <th id="T_a664c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a664c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a664c_row1_col1" class="data row1 col1" >quality</td>
#     </tr>
#     <tr>
#       <th id="T_a664c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
diabetes_df = setup(diabetes,target='Outcome')
diabetes_df
# Out:
# <style type="text/css">
# #T_bb0bc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bb0bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb0bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bb0bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb0bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb0bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bb0bc_row0_col1" class="data row0 col1" >1470</td>
#     </tr>
#     <tr>
#       <th id="T_bb0bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb0bc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bb0bc_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_bb0bc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Compare Models

# %%
crop_df = compare_models()
# Out:
# <style type="text/css">
# #T_ced35 th {
#   text-align: left;
# }
# ...

# %%
print(crop_df)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1596, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
type(crop_df)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %%
wine_df = compare_models()
# Out:
# <style type="text/css">
# #T_d97d5 th {
#   text-align: left;
# }
# ...

# %%
print(wine_df)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=2019, verbose=0, warm_start=False)

# %%
type(wine_df)
# Out:
# sklearn.ensemble._forest.RandomForestClassifier

# %%
diabetes_df = compare_models()
# Out:
# <style type="text/css">
# #T_bf8f7 th {
#   text-align: left;
# }
# ...

# %%
print(diabetes_df)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1470, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
type(diabetes_df)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %% [markdown]
# # Creates Model For Crop Dataset

# %% [markdown]
# ### * Naive Bayes

# %%
model = create_model('nb')
# Out:
# <style type="text/css">
# #T_8cc00_row10_col0, #T_8cc00_row10_col1, #T_8cc00_row10_col2, #T_8cc00_row10_col3, #T_8cc00_row10_col4, #T_8cc00_row10_col5, #T_8cc00_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8cc00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cc00_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8cc00_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8cc00_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8cc00_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8cc00_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8cc00_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8cc00_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(model)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
type(model)
# Out:
# sklearn.naive_bayes.GaussianNB

# %% [markdown]
# ### *Random Forest Classifier

# %%
model_rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_f8e62_row10_col0, #T_f8e62_row10_col1, #T_f8e62_row10_col2, #T_f8e62_row10_col3, #T_f8e62_row10_col4, #T_f8e62_row10_col5, #T_f8e62_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f8e62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8e62_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f8e62_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f8e62_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f8e62_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f8e62_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f8e62_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f8e62_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(model_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=5680, verbose=0, warm_start=False)

# %%
type(model_rf)
# Out:
# sklearn.ensemble._forest.RandomForestClassifier

# %%
model_rf.feature_importances_
# Out:
# array([0.10334122, 0.15560079, 0.16908346, 0.07262904, 0.2136116 ,
#        0.05503703, 0.23069686])

# %% [markdown]
# # Tune Model

# %%
tune_model = tune_model('model')

# %% [markdown]
# # Ensemble model

# %%
rf_bagging = ensemble_model(model_rf,method='Bagging')
# Out:
# <style type="text/css">
# #T_f20b5_row10_col0, #T_f20b5_row10_col1, #T_f20b5_row10_col2, #T_f20b5_row10_col3, #T_f20b5_row10_col4, #T_f20b5_row10_col5, #T_f20b5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f20b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f20b5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f20b5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f20b5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f20b5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f20b5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f20b5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f20b5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
rf_boosting = ensemble_model(model_rf,method='Boosting')
# Out:
# <style type="text/css">
# #T_70dd7_row10_col0, #T_70dd7_row10_col1, #T_70dd7_row10_col2, #T_70dd7_row10_col3, #T_70dd7_row10_col4, #T_70dd7_row10_col5, #T_70dd7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_70dd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70dd7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_70dd7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_70dd7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_70dd7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_70dd7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_70dd7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_70dd7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# # Evaluate Model

# %%
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Interpret Model

# %%
interpret_model(model_rf)

# %%
interpret_model(model_rf, plot='reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# # Deploy Model

# %% [markdown]
# # Save Model
